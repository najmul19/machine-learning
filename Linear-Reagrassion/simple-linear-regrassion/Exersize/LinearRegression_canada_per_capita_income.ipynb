# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("canada_per_capita_income.csv");
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# %matplotlib inline
plt.xlabel("year")
plt.ylabel("per capita income (US$)")
plt.scatter(df.year, df["per capita income (US$)"], color='red',marker="+")
## option 2 : df.columns = df.columns.str.replace(' ', '_') 
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["year"]],df[["per capita income (US$)"]])
## df.rename(columns={"per capita income (US$)": "income"}, inplace=True)
## reg.fit(df[["year"]], df[["income"]])
print("Slope (m):", reg.coef_)
print("Intercept (b):", reg.intercept_)
# Out:
# Slope (m): [[828.46507522]]
# Intercept (b): [-1632210.75785546]

# %%
reg.predict(pd.DataFrame([[2005]], columns=["year"]))
# Out:
# array([[28861.71796608]])

# %%
## y= m*x+b
828.46507522*2005+(-1632210.75785546)
# Out:
# 28861.71796064009

# %%
# %matplotlib inline
plt.xlabel("year")
plt.ylabel("per capita income (US$)")
plt.scatter(df[["year"]], df[["per capita income (US$)"]], color='red',marker="+")
plt.plot(df["year"], reg.predict(df[['year']]),color='blue')
plt.show()
